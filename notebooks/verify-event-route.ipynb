# %%
import requests
path = "/api/events/"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
print(endpoint)
# Out:
# http://localhost:8002/api/events/

# %%
response = requests.get(endpoint)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
# Out:
# {'results': [{'id': 1, 'page': '', 'description': ''}, {'id': 2, 'page': '', 'description': ''}, {'id': 3, 'page': '', 'description': ''}], 'count': 3} <class 'dict'> None

# %%
data = {"page": "/test+"}

# %%
import json
json.dumps(data)
# Out:
# '{"page": "/test+"}'

# %%
headers = {
    "Content-Type": "application/json"
}
response = requests.post(endpoint, data=json.dumps(data), headers=headers)
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 25 May 2026 17:37:07 GMT', 'server': 'uvicorn', 'content-length': '43', 'content-type': 'application/json'}
# ok True
# {'id': 123, 'page': '/test+', 'description': ''} <class 'dict'> None

# %%
detail_path = "/api/events/12"
base_url = "http://localhost:8002"
detail_endpoint = f"{base_url}{detail_path}" 
print(detail_endpoint)

headers = {
    "Content-Type": "application/json"
}

response = requests.put(detail_endpoint, json={"description": "hello world"}, headers=headers)

print(response.headers)
print('ok', response.ok)
if response.ok:
    data_put = response.json()
    print(data_put, type(data_put))
else:
    print(response.text)
# Out:
# http://localhost:8002/api/events/12
# {'date': 'Mon, 25 May 2026 17:37:09 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'hello world'} <class 'dict'>

# %%
path = "/api/events/"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 25 May 2026 17:37:16 GMT', 'server': 'uvicorn', 'content-length': '43', 'content-type': 'application/json'}
# ok True
# {'id': 123, 'page': '/test+', 'description': ''} <class 'dict'> None
